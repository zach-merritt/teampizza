# %% [markdown]
# ### Random Acts of Pizza - Baseline Model & EDA
# ## Authors: Ben Arnoldy, Mary Boardman, Zach Merritt, and Kevin Gifford
# #### Kaggle Competition Description:
# In machine learning, it is often said there are no free lunches. How wrong we were.
#
# This competition contains a dataset with 5671 textual requests for pizza from the Reddit community Random Acts of Pizza together with their outcome (successful/unsuccessful) and meta-data. Participants must create an algorithm capable of predicting which requests will garner a cheesy (but sincere!) act of kindness.
#
# "I'll write a poem, sing a song, do a dance, play an instrument, whatever! I just want a pizza," says one hopeful poster. What about making an algorithm?
#
# Kaggle is hosting this competition for the machine learning community to use for fun and practice. This data was collected and graciously shared by Althoff et al. (Buy them a pizza -- data collection is a thankless and tedious job!) We encourage participants to explore their accompanying paper and ask that you cite the following reference in any publications that result from your work:
#
# Tim Althoff, Cristian Danescu-Niculescu-Mizil, Dan Jurafsky. How to Ask for a Favor: A Case Study on the Success of Altruistic Requests, Proceedings of ICWSM, 2014.
# _______________________________________________________________________________________________

# %% [markdown]
# ## Notebook Title: EDA & Model Baseline
# #### Purpose: Load the 'Random Acts of Pizza' train and test data. Conduct an exploratory data analysis to gain an understanding of the data. Create a baseline Logisitic Regression model using non-text (numeric) fields only.

# %% [markdown]
# ## I. Load Data and Modules, Process Data

# %% [markdown]
# ### A. Load Data and Modules

# %%
import json
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib.colors import ListedColormap
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from subprocess import check_output
#from wordcloud import WordCloud, STOPWORDS

#ML
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GMM
from sklearn.mixture import GaussianMixture

from sklearn.decomposition import TruncatedSVD
from sklearn.random_projection import sparse_random_matrix

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

from sklearn.pipeline import make_pipeline

# %matplotlib inline
plt.style.use('bmh')

# %%
#1. Train Data
with open('../data/train.json') as fin:
    trainjson = json.load(fin)
train = pd.io.json.json_normalize(trainjson)
#2. Test Data
with open('../data/test.json') as fin:
    testjson = json.load(fin)
test = pd.io.json.json_normalize(testjson)

print("Train Shape:", train.shape)
print("Test Shape:", test.shape)
# Out:
# Train Shape: (4040, 32)
# Test Shape: (1631, 17)

# %% [markdown]
# ### B1. Find any missing values

# %%
train.isnull().sum()
# Out:
# giver_username_if_known                                    0
# number_of_downvotes_of_request_at_retrieval                0
# number_of_upvotes_of_request_at_retrieval                  0
# post_was_edited                                            0
# request_id                                                 0
# request_number_of_comments_at_retrieval                    0
# request_text                                               0
# request_text_edit_aware                                    0
# request_title                                              0
# requester_account_age_in_days_at_request                   0
# requester_account_age_in_days_at_retrieval                 0
# requester_days_since_first_post_on_raop_at_request         0
# requester_days_since_first_post_on_raop_at_retrieval       0
# requester_number_of_comments_at_request                    0
# requester_number_of_comments_at_retrieval                  0
# requester_number_of_comments_in_raop_at_request            0
# requester_number_of_comments_in_raop_at_retrieval          0
# requester_number_of_posts_at_request                       0
# requester_number_of_posts_at_retrieval                     0
# requester_number_of_posts_on_raop_at_request               0
# requester_number_of_posts_on_raop_at_retrieval             0
# requester_number_of_subreddits_at_request                  0
# requester_received_pizza                                   0
# requester_subreddits_at_request                            0
# requester_upvotes_minus_downvotes_at_request               0
# requester_upvotes_minus_downvotes_at_retrieval             0
# requester_upvotes_plus_downvotes_at_request                0
# requester_upvotes_plus_downvotes_at_retrieval              0
# requester_user_flair                                    3046
# requester_username                                         0
# unix_timestamp_of_request                                  0
# unix_timestamp_of_request_utc                              0
# dtype: int64

# %% [markdown]
# No missing data except in column "requester_user_flair." We see in the next section that this isn't a column in the test data, so we may just elect to not use it to train the model.

# %% [markdown]
# ### B2. Identify common columns between test and train

# %%
print("Common columns in train and test:")
print(train.columns[train.columns.isin(test.columns)])
print("----")
print("Columns in train but NOT test:")
print(train.columns[~train.columns.isin(test.columns)])
# Out:
# Common columns in train and test:
# Index(['giver_username_if_known', 'request_id', 'request_text_edit_aware',
#        'request_title', 'requester_account_age_in_days_at_request',
#        'requester_days_since_first_post_on_raop_at_request',
#        'requester_number_of_comments_at_request',
#        'requester_number_of_comments_in_raop_at_request',
#        'requester_number_of_posts_at_request',
#        'requester_number_of_posts_on_raop_at_request',
#        'requester_number_of_subreddits_at_request',
#        'requester_subreddits_at_request',
#        'requester_upvotes_minus_downvotes_at_request',
#        'requester_upvotes_plus_downvotes_at_request', 'requester_username',
#        'unix_timestamp_of_request', 'unix_timestamp_of_request_utc'],
#       dtype='object')
# ----
# Columns in train but NOT test:
# Index(['number_of_downvotes_of_request_at_retrieval',
#        'number_of_upvotes_of_request_at_retrieval', 'post_was_edited',
#        'request_number_of_comments_at_retrieval', 'request_text',
#        'requester_account_age_in_days_at_retrieval',
#        'requester_days_since_first_post_on_raop_at_retrieval',
#        'requester_number_of_comments_at_retrieval',
#        'requester_number_of_comments_in_raop_at_retrieval',
#        'requester_number_of_posts_at_retrieval',
#        'requester_number_of_posts_on_raop_at_retrieval',
#        'requester_received_pizza',
#        'requester_upvotes_minus_downvotes_at_retrieval',
#        'requester_upvotes_plus_downvotes_at_retrieval',
#        'requester_user_flair'],
#       dtype='object')

# %% [markdown]
# As can be seen above, there is a series of columns in the training data only. These columns reflect data about the post (e.g., the #of upvotes) at the time this Reddit data was retrieved. We use certain supervised and unsupversied techniques to derive value from this data (even though that information is not provided on the data set we will be predicting).

# %% [markdown]
# ### C. Create training data, labels, and special 'in training only' data

# %%
train_labels_master = train[['requester_received_pizza']]
train_data_master = train[test.columns & train.columns]
train_only_data_master = train[train.columns[~train.columns.isin(test.columns)]].drop(['requester_received_pizza'], axis = 1)

# %%
print(train.shape, train_data_master.shape)
# Out:
# (4040, 32) (4040, 17)

# %% [markdown]
# ### D. Set column types and profile

# %%
train_data_master = train_data_master.assign(
    unix_timestamp_of_request = pd.to_datetime(
        train_data_master.unix_timestamp_of_request, unit = "s"),
    unix_timestamp_of_request_utc = pd.to_datetime(
        train_data_master.unix_timestamp_of_request_utc, unit = "s"))

# %%
train_data_master.describe()
train_data_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4040 entries, 0 to 4039
# Data columns (total 17 columns):
# giver_username_if_known                               4040 non-null object
# request_id                                            4040 non-null object
# request_text_edit_aware                               4040 non-null object
# request_title                                         4040 non-null object
# requester_account_age_in_days_at_request              4040 non-null float64
# requester_days_since_first_post_on_raop_at_request    4040 non-null float64
# requester_number_of_comments_at_request               4040 non-null int64
# requester_number_of_comments_in_raop_at_request       4040 non-null int64
# requester_number_of_posts_at_request                  4040 non-null int64
# requester_number_of_posts_on_raop_at_request          4040 non-null int64
# requester_number_of_subreddits_at_request             4040 non-null int64
# requester_subreddits_at_request                       4040 non-null object
# requester_upvotes_minus_downvotes_at_request          4040 non-null int64
# requester_upvotes_plus_downvotes_at_request           4040 non-null int64
# requester_username                                    4040 non-null object
# unix_timestamp_of_request                             4040 non-null datetime64[ns]
# unix_timestamp_of_request_utc                         4040 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(7), object(6)
# memory usage: 536.6+ KB

# %% [markdown]
# ## V. Dimensionality Reduction

# %%
# Ben: I think there's a flaw here, see next module that overwrites this vectorization.

# Use a CountVectorizer to vectorize the data, since it is text-based
vectorizer = CountVectorizer()
vtrain = vectorizer.fit_transform(train)
vtest = vectorizer.fit_transform(test)

# Since PCA does not work for a sparse matrix, we are using Truncated SVD instead for dimensionality reduction
for i in range (1, 32):
    svd = TruncatedSVD(n_components = i)
    svd.fit(vtrain)
    print(svd.explained_variance_ratio_)
# Out:
# [0.03163969]
# [0.0315655  0.03199951]
# [0.03080566 0.03220849 0.03221825]
# [0.03205929 0.03099064 0.03189559 0.02935717]
# [0.03223867 0.0322578  0.03070787 0.02977631 0.03164424]
# [0.03217571 0.0288946  0.03215107 0.032258   0.03205605 0.03181297]
# [0.03034429 0.03200176 0.03222116 0.03219253 0.03179278 0.02815241
#  0.03103143]
# [0.03225223 0.03014381 0.03009852 0.02867053 0.02942262 0.03225174
#  0.03078693 0.0316222 ]
# [0.03224751 0.02981539 0.03223719 0.03213725 0.03222411 0.03223742
#  0.03206354 0.03102892 0.02855543]
# [0.03026163 0.03220806 0.03134236 0.02905604 0.03200534 0.03072658
#  0.03225774 0.03199093 0.03077512 0.03209766]
# [0.03046625 0.0320937  0.03206688 0.03134698 0.03220945 0.03155552
#  0.03216293 0.03099523 0.03142336 0.02945112 0.03012249]
# [0.03225774 0.02933543 0.03113929 0.03222419 0.03217175 0.03166734
#  0.03082333 0.03215186 0.03176776 0.03224743 0.03224272 0.03225805]
# [0.03130046 0.03182427 0.02889369 0.0319497  0.03196569 0.02698449
#  0.03148088 0.02905024 0.0322558  0.03198093 0.03225362 0.03225199
#  0.03109896]
# [0.03083109 0.03225806 0.03205144 0.03144352 0.03217846 0.03121902
#  0.03181064 0.02814487 0.03220246 0.03206218 0.03217337 0.02579567
#  0.03147396 0.03213546]
# [0.03210432 0.0303394  0.03221797 0.03114869 0.03208312 0.02998189
#  0.03210849 0.03223962 0.02869348 0.03224361 0.0308499  0.03224354
#  0.0321768  0.02842032 0.03186703]
# [0.02954683 0.02940614 0.03223618 0.03112449 0.03212853 0.03221005
#  0.03224289 0.03177692 0.03021125 0.03178643 0.0310732  0.03181986
#  0.0321536  0.03028626 0.0322417  0.03213255]
# [0.03224024 0.03220155 0.03225605 0.03225036 0.03224521 0.02711041
#  0.03211143 0.03223584 0.03186271 0.03137524 0.03224032 0.02882997
#  0.03149413 0.0302162  0.03130773 0.03225535 0.03203602]
# [0.03188275 0.03187552 0.03217251 0.03223205 0.03217886 0.03128722
#  0.0313477  0.03195766 0.03224231 0.03217745 0.03202017 0.03224161
#  0.02978317 0.03222607 0.032072   0.03212859 0.03132974 0.03155314]
# [0.03154614 0.03221005 0.03185412 0.03034834 0.03179471 0.03032084
#  0.02798741 0.03213517 0.03188833 0.03223343 0.03214618 0.03028323
#  0.03049205 0.03223325 0.03021634 0.03203168 0.03201935 0.0319664
#  0.02881675]
# [0.02950909 0.03221687 0.03206455 0.03216259 0.03214473 0.03209909
#  0.03047919 0.03224331 0.03225136 0.03157116 0.03131477 0.02788419
#  0.02881315 0.03168708 0.03223522 0.03179682 0.03173442 0.02698558
#  0.03084024 0.03221926]
# [0.03102159 0.03188914 0.03100919 0.03219895 0.0320004  0.0318903
#  0.03090976 0.0315169  0.03192391 0.03223693 0.03197887 0.03174423
#  0.0302287  0.03225712 0.0256979  0.03216297 0.03221773 0.03213659
#  0.03215214 0.03177389 0.03170312]
# [0.03216198 0.03055474 0.03136129 0.02932685 0.03204311 0.03199135
#  0.0307018  0.03174106 0.03121326 0.03157419 0.02951211 0.02992141
#  0.03196479 0.03182741 0.03150184 0.03210572 0.03225804 0.03225497
#  0.03156067 0.03178353 0.02970833 0.03202765]
# [0.03224063 0.03216606 0.02915298 0.03225716 0.03198991 0.03154731
#  0.03092665 0.03223214 0.03223899 0.03077341 0.03173139 0.02738016
#  0.03211088 0.0308307  0.03153807 0.03159148 0.03208087 0.03160208
#  0.03161903 0.03206507 0.03212106 0.03198114 0.03213195]
# [0.03195246 0.03060307 0.03221866 0.0272268  0.03037822 0.029341
#  0.03184407 0.03225324 0.03225788 0.03194808 0.03202998 0.03225212
#  0.0317906  0.03177878 0.03181228 0.03205319 0.03047434 0.02944754
#  0.03223146 0.03206056 0.03162896 0.0316742  0.03132696 0.03217366]
# [0.03029624 0.03212867 0.03014885 0.03215744 0.03106348 0.03125
#  0.03216827 0.02969498 0.03203309 0.032157   0.03208258 0.03222456
#  0.03189631 0.0318873  0.03198994 0.03092958 0.03160765 0.03104738
#  0.02972864 0.0317872  0.03225703 0.02908435 0.0263347  0.03224272
#  0.03225676]
# [0.03059639 0.03081213 0.032155   0.02777222 0.03221458 0.03208746
#  0.03173998 0.03038506 0.0322004  0.03215202 0.03110667 0.03077475
#  0.03127036 0.03225388 0.03225033 0.03205999 0.03211795 0.02518188
#  0.03215698 0.03223872 0.03218049 0.03064115 0.03218817 0.03027566
#  0.03221637 0.03161947]
# [0.03176831 0.03208695 0.03217552 0.0320985  0.03177038 0.03040061
#  0.03211979 0.0314642  0.03224385 0.03006519 0.03222056 0.03209164
#  0.03168561 0.0322507  0.02725218 0.03125    0.03199408 0.03079115
#  0.03185739 0.03106799 0.03087385 0.03182727 0.03085228 0.03100052
#  0.0321684  0.03225796 0.0319152 ]
# [0.03046692 0.02990111 0.03204486 0.03224569 0.03196863 0.03119636
#  0.0322504  0.03224211 0.0316628  0.0263501  0.03224594 0.03114088
#  0.03011879 0.0322507  0.03073534 0.03149359 0.03214646 0.03125
#  0.03217881 0.03209113 0.03184378 0.0319096  0.03110443 0.03018585
#  0.03118107 0.03167868 0.0304373  0.03177453]
# [0.02593006 0.03188275 0.02995628 0.0322226  0.03218992 0.02787272
#  0.03139782 0.0318922  0.03211059 0.03222511 0.03123795 0.03100266
#  0.03199177 0.03125    0.03224674 0.03135634 0.03224472 0.03005835
#  0.03214992 0.03148704 0.03220534 0.03220968 0.03191211 0.02779192
#  0.03224493 0.03215599 0.03104316 0.03177502 0.02955728]
# [0.03164096 0.03196361 0.03150127 0.03218637 0.03183704 0.03179715
#  0.02981905 0.02840502 0.03205018 0.02917759 0.03143819 0.0318493
#  0.03181804 0.03181928 0.03125    0.03220923 0.02890977 0.03201557
#  0.03224028 0.03205652 0.03131007 0.03141181 0.03040209 0.03197115
#  0.03139289 0.02991524 0.03055682 0.03205683 0.03223812 0.02830126]
# [0.03194777 0.03208823 0.03158015 0.03197252 0.03195623 0.03088536
#  0.03224218 0.03129378 0.03125    0.02388338 0.03213058 0.03146483
#  0.02936155 0.03214153 0.0320192  0.03024745 0.03163952 0.03169126
#  0.02907863 0.03182406 0.03205386 0.03086873 0.03073707 0.03096738
#  0.03189677 0.03103318 0.03212723 0.03215186 0.03222813 0.03225747
#  0.03214551]

# %% [markdown]
# ### A. Creating Dimension-Reduced Data Sets with Number of Components 2-6

# %%
# Instead of a for-loop, we created separate data sets, using separate variables for each. 

svd_2 = TruncatedSVD(n_components = 2)
vtrain_2 = svd_2.fit(vtrain)
print(svd_2.explained_variance_ratio_)

svd_3 = TruncatedSVD(n_components = 3)
vtrain_3 = svd_3.fit(vtrain)
print(svd_3.explained_variance_ratio_)

svd_4 = TruncatedSVD(n_components = 4)
vtrain_4 = svd_4.fit(vtrain)
print(svd_4.explained_variance_ratio_)

svd_5 = TruncatedSVD(n_components = 5)
vtrain_5 = svd_5.fit(vtrain)
print(svd_5.explained_variance_ratio_)

svd_6 = TruncatedSVD(n_components = 6)
vtrain_6 = svd_6.fit(vtrain)
print(svd_6.explained_variance_ratio_)
# Out:
# [0.03213592 0.0313942 ]
# [0.0225005  0.03225801 0.03180073]
# [0.030166   0.02972496 0.02937952 0.03225736]
# [0.03114726 0.03223654 0.03222071 0.03199906 0.03173548]
# [0.03189844 0.03158054 0.03177055 0.03203356 0.03105584 0.03188225]

# %% [markdown]
# ### B. K-Means

# %%
raw_score = []
for i in range(1,21):
    kmeans_raw = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans_raw.fit(vtrain)
    y_hat_kmeans_raw = kmeans_raw.predict(vtrain)
    centers = kmeans_raw.cluster_centers_
#     print('The KMeans score for the raw data, using',i,'clusters is:',kmeans_raw.score(vtrain[y_hat_kmeans_raw]))
    raw_score.append(kmeans_raw.score(vtrain[y_hat_kmeans_raw]))
print(raw_score)

svd_2 = TruncatedSVD(n_components = 2)
normalizer = Normalizer(copy=False)
lsa_2 = make_pipeline(svd_2, normalizer)
vtrain_lsa2 = lsa_2.fit_transform(vtrain)

score_2 = []
for i in range(1,21):
    kmeans2 = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans2.fit(vtrain_lsa2)
    y_hat_kmeans2 = kmeans2.predict(vtrain_lsa2)
    centers = kmeans2.cluster_centers_
#     print('The KMeans score for the truncated, 2 component data, using',i,'clusters is:',
#           kmeans2.score(vtrain_lsa2[y_hat_kmeans]))
    score_2.append(kmeans2.score(vtrain_lsa2[y_hat_kmeans2]))
print(score_2)

svd_3 = TruncatedSVD(n_components = 3)
normalizer = Normalizer(copy=False)
lsa_3 = make_pipeline(svd_3, normalizer)
vtrain_lsa3 = lsa_3.fit_transform(vtrain)

score_3 = []
for i in range(1,21):
    kmeans3 = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans3.fit(vtrain_lsa3)
    y_hat_kmeans3 = kmeans3.predict(vtrain_lsa3)
    centers = kmeans3.cluster_centers_
#     print('The KMeans score for the truncated, 3 component data, using',i,'clusters is:',
#           kmeans3.score(vtrain_lsa3[y_hat_kmeans3]))
    score_3.append(kmeans3.score(vtrain_lsa3[y_hat_kmeans3]))
print(score_3)

svd_4 = TruncatedSVD(n_components = 4)
normalizer = Normalizer(copy=False)
lsa_4 = make_pipeline(svd_4, normalizer)
vtrain_lsa4 = lsa_4.fit_transform(vtrain)

score_4 = []
for i in range(1,21):
    kmeans4 = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans4.fit(vtrain_lsa4)
    y_hat_kmeans4 = kmeans4.predict(vtrain_lsa4)
    centers = kmeans4.cluster_centers_
#     print('The KMeans score for the truncated, 4 component data, using',i,'clusters is:',
#           kmeans4.score(vtrain_lsa4[y_hat_kmeans4]))
    score_4.append(kmeans4.score(vtrain_lsa4[y_hat_kmeans4]))
print(score_4)

svd_5 = TruncatedSVD(n_components = 5)
normalizer = Normalizer(copy=False)
lsa_5 = make_pipeline(svd_5, normalizer)
vtrain_lsa5 = lsa_5.fit_transform(vtrain)

score_5 = []
for i in range(1,21):
    kmeans5 = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans5.fit(vtrain_lsa5)
    y_hat_kmeans5 = kmeans5.predict(vtrain_lsa5)
    centers = kmeans5.cluster_centers_
#     print('The KMeans score for the truncated, 5 component data, using',i,'clusters is:',
#           kmeans5.score(vtrain_lsa5[y_hat_kmeans5]))
    score_5.append(kmeans5.score(vtrain_lsa5[y_hat_kmeans5]))
print(score_5)

svd_6 = TruncatedSVD(n_components = 6)
normalizer = Normalizer(copy=False)
lsa_6 = make_pipeline(svd_6, normalizer)
vtrain_lsa6 = lsa_6.fit_transform(vtrain)

score_6 = []
for i in range(1,21):
    kmeans6 = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=1, verbose=False)
    kmeans6.fit(vtrain_lsa6)
    y_hat_kmeans6 = kmeans6.predict(vtrain_lsa6)
    centers = kmeans6.cluster_centers_
#     print('The KMeans score for the truncated, 6 component data, using',i,'clusters is:',
#           kmeans5.score(vtrain_lsa6[y_hat_kmeans6]))
    score_6.append(kmeans6.score(vtrain_lsa6[y_hat_kmeans6]))
print(score_6)

# # The plot below wasn't doing much for me
# fig = plt.figure(0,figsize=(32,32))
# ax = fig.add_subplot(4,4,2)

# # Draw the plots
# ax.scatter(vtrain_lsa2[:, 0], vtrain_lsa2[:, 1], s=1, c=y_hat_kmeans)
# ax.scatter(centers[:, 0], centers[:, 1], c='red', s=50, alpha=0.6)
# ax.grid()
# Out:
# [-31.0, -30.967741935483893, -30.93333333333331, -30.896551724137915, -30.85714285714287, -29.85185185185184, -30.769230769230745, -28.80000000000002, -25.874999999999993, -4.782608695652174, -26.72727272727272, -28.571428571428573, -6.65, -8.526315789473685, -7.555555555555556, -7.529411764705883, -23.4375, -8.4, -8.357142857142858, -17.53846153846154]
# [-31.813714467374762, -31.95585334482133, -8.78938361640522, -9.113889358721668, -1.7051294116722233, -4.167141217945089, -2.312540498258147, -1.346070147719996, -0.6106277707162895, -0.3412012361624923, -0.5502208463977898, -0.22627520838138426, -0.2359576371268325, -0.21649917760318071, -0.06859819973877557, -0.10155681098327374, -0.0778913848435574, -0.047325429605758584, -0.059617691039623444, -0.04262895337641048]
# [-29.33718755321352, -12.874667079125658, -14.715709765858833, -14.281051021596326, -7.530867455246137, -6.867398531310579, -5.404019106225446, -3.8068844098342485, -3.424010076497047, -3.5366825191412223, -1.5751606034687924, -0.8879303043381852, -2.174831697787248, -1.5668011983256358, -1.4876633386456668, -1.019905762084381, -0.6481859627291071, -0.5586137798892572, -0.44567625431931934, -0.4702485953233059]
# [-26.500107784472505, -21.968678653207004, -11.803602536987215, -18.013497923936296, -9.734791786046657, -7.748356818688402, -7.844253209834548, -7.494165618781094, -5.964534451513066, -6.418431163648709, -4.341492650327671, -4.376869236956992, -5.093090521045873, -4.098273119030087, -2.6189296933160358, -2.663014512167973, -2.717850998172279, -1.5617632332084077, -1.4856735907124532, -1.7030891836312199]
# [-33.14884995974657, -31.773377180014986, -10.937634257836168, -17.873618830220085, -8.878808227421853, -10.04392251906637, -11.28459762347771, -8.634453135910984, -6.962898583464597, -6.173385419932556, -5.503328307420532, -7.131748871748067, -5.195057531155012, -5.54774430464937, -2.417841546283797, -3.4734593939846343, -4.298175002250882, -2.486684407973588, -2.2113624956592575, -2.27645828332033]
# [-36.986643099137375, -34.6780102033443, -22.676966395279415, -18.248468073403153, -17.07562118975088, -14.299037519016998, -15.096977988771727, -9.273162695335074, -10.066023672074758, -7.344000669570642, -8.820043268790187, -8.279239068852835, -7.604933989774154, -6.330776352300767, -6.422790921989515, -4.782900315630095, -4.6331286662432305, -6.105689623322407, -4.859518711785176, -3.934381238834018]

# %% [markdown]
# ### C. Gaussian Mixture Model

# %%
# The model using the raw data fit the train data, but wouldn't predict the test data, as it wasn't the right shape. 
# I think this goes back to the different dimensionality between the two data sets. 
# vtraind = vtrain.toarray()
# vtestd = vtest.toarray()
# gmm = GaussianMixture()
# gmm.fit(vtraind)
# gmm.predict(vtestd)

svd_2 = TruncatedSVD(n_components = 2)
normalizer = Normalizer(copy=False)
lsa_2 = make_pipeline(svd_2, normalizer)
vtrain_lsa2 = lsa_2.fit_transform(vtrain)

svd_2_test = TruncatedSVD(n_components = 2)
normalizer = Normalizer(copy=False)
lsa_2_test = make_pipeline(svd_2_test, normalizer)
vtest_lsa2 = lsa_2_test.fit_transform(vtest)

gmm2 = GaussianMixture()
gmm2.fit(vtrain_lsa2)
gmm2.score_samples(vtest_lsa2)
# Out:
# array([-2.78313504, -2.46044602, -1.77482327, -2.66870707, -2.39800844,
#        -1.95153826, -1.80927258, -1.91405487, -2.77124911, -2.80525743,
#        -1.80969685, -1.78482881, -1.80843819, -1.7812644 , -2.50727568,
#        -2.40418066, -2.20870235])

# %%
# Separate out the train data with positive labels, fit the GMM model
p2pos = train[train_labels_master == 1]
pos = GaussianMixture(n_components=4, covariance_type='full')
pos.fit(p2pos)

# Separate out the train data with negative labels, fit the GMM model    
p2neg = train[train_labels_master != 1]    
neg = GaussianMixture(n_components=4, covariance_type='full')
neg.fit(p2neg)

# Fit the test data to both models
wlprob_pos = pos.score_samples(test)
wlprob_neg = neg.score_samples(test)

# Create an array that picks the winner from each prediction 
pred_test_labels = np.array(wlprob_pos > wlprob_neg).astype(int)

# Calculate the accuracy to 6 decimal places, print it out
accuracy = np.round(np.mean(pred_test_labels == test_labels), 6)   
print('The accuracy of this model is:', accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-21e9fc05979d> in <module>()
#       2 p2pos = train[train_labels_master == 1]
#       3 pos = GaussianMixture(n_components=4, covariance_type='full')
# ----> 4 pos.fit(p2pos)
#       5
#       6 # Separate out the train data with negative labels, fit the GMM model
#
# ~\Anaconda3\lib\site-packages\sklearn\mixture\base.py in fit(self, X, y)
#     188         self
#     189         """
# --> 190         X = _check_X(X, self.n_components)
#     191         self._check_initial_parameters(X)
#     192
#
# ~\Anaconda3\lib\site-packages\sklearn\mixture\base.py in _check_X(X, n_components, n_features)
#      52     X : array, shape (n_samples, n_features)
#      53     """
# ---> 54     X = check_array(X, dtype=[np.float64, np.float32])
#      55     if n_components is not None and X.shape[0] < n_components:
#      56         raise ValueError('Expected n_samples >= n_components '
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# # Ben's fix attempt
# I've opted to do this in separate cells just in case I royally screw up.

# %% [markdown]
# ### Redo of Vectorizer

# %%
# I believe we cannot just vectorize the train data because the text-based data
# is held within one specific feature called request_test_edit_aware.
# Below I repurposed some of Zach's code to vectorize

#Create Sparse matrix of words
count_vect = CountVectorizer()
#Split train and test data
x_train, x_test, y_train, y_test = train_test_split(
    count_vect.fit_transform(train_data_master['request_text_edit_aware']), 
    train_labels_master.values.ravel(), test_size=0.2, random_state=0)
cv_feature_names = count_vect.get_feature_names()

# %% [markdown]
# ### Apply SVD (in lieu of PCA)

# %%
# Since PCA does not work for a sparse matrix, we are using Truncated SVD instead for dimensionality reduction
for top_comps in range (1, 15):
    svd = TruncatedSVD(n_components = top_comps)
    svd.fit(x_train)
    print(svd.explained_variance_ratio_)
# Out:
# [0.01244676]
# [0.01244676 0.00897866]
# [0.01244676 0.00898016 0.00664245]
# [0.01244676 0.00898008 0.00667929 0.00557261]
# [0.01244676 0.00898018 0.00668307 0.00558065 0.00522323]
# [0.01244676 0.00898016 0.0066827  0.00558402 0.00523113 0.00472077]
# [0.01244676 0.0089801  0.0066829  0.00558132 0.00520619 0.00474393
#  0.00451474]
# [0.01244676 0.00898008 0.00668361 0.00558562 0.00523782 0.00475221
#  0.00456518 0.00411874]
# [0.01244676 0.00898017 0.00668291 0.00558658 0.00523422 0.00477128
#  0.00457009 0.00417045 0.00405914]
# [0.01244676 0.00898024 0.00668317 0.00558338 0.0052387  0.00477584
#  0.00456951 0.00418864 0.00402338 0.00397552]
# [0.01244676 0.00898013 0.0066842  0.00557716 0.00522347 0.00477272
#  0.00456394 0.00419025 0.00406031 0.00391013 0.00387412]
# [0.01244676 0.00898024 0.00668403 0.00558865 0.00523844 0.00477422
#  0.00458147 0.00419812 0.00405912 0.00396595 0.00395601 0.00379379]
# [0.01244676 0.00898019 0.00668322 0.00558726 0.00523893 0.00477365
#  0.00456305 0.0041581  0.004098   0.00392414 0.0038929  0.00380999
#  0.00362556]
# [0.01244676 0.00898023 0.00668322 0.00558941 0.00523853 0.00477401
#  0.00457177 0.00419056 0.00409913 0.00396236 0.00394657 0.00380374
#  0.00365464 0.00360133]

# %%
# The output of vectorizer shows a major dropoff in explained variance after the 1st component
# This suggests that projecting down to 1 component might be best.

# %% [markdown]
# ### Try various hyperparameters with GMM

# %%
def train_gmm(svd_comps = 2, gmm_comps = 4, cov_type = 'full', sparse = True):
    
    # project data to few dimensions using SVD if sparse, PCA if dense
    if (sparse): svd_test = TruncatedSVD(n_components=svd_comps)
    else: svd_test = PCA(n_components=svd_comps)
    svd_test_ft = svd_test.fit_transform(x_test)
    if (sparse): svd_train = TruncatedSVD(n_components=svd_comps)
    else: svd_train = PCA(n_components=svd_comps)
    svd_train_ft = svd_train.fit_transform(x_train)

    # create two sets of svd data, one that's positively labeled, one that's negatively labeled
    pos_svd = svd_train_ft[y_train == 1]
    neg_svd = svd_train_ft[y_train == 0]
    
    # fit a GMM for pos and neg datasets
    gmm_pos = GaussianMixture(n_components=gmm_comps, covariance_type=cov_type) 
    gmm_fit_pos = gmm_pos.fit(pos_svd)
    gmm_neg = GaussianMixture(n_components=gmm_comps, covariance_type=cov_type) 
    gmm_fit_neg = gmm_neg.fit(neg_svd)
    
    prediction = np.ndarray(shape=y_test.shape)
    
    for sample in range(svd_test_ft.shape[0]):
        pos_score = gmm_fit_pos.score(svd_test_ft[sample].reshape(1,-1))
        neg_score = gmm_fit_neg.score(svd_test_ft[sample].reshape(1, -1))
        # make pick
        if (pos_score >= neg_score): prediction[sample] = 1
        else: prediction[sample] = 0 

    # calculate accuracy
    accuracy = metrics.accuracy_score(y_test, prediction)
    # f1 = metrics.f1_score(y_test, prediction)
    print("Accuracy score for", svd_comps,"SVD comps,",gmm_comps,"GMM comps,","Covariance type",cov_type,"=",accuracy)

    return(accuracy)

def gmm_trials(sparse = True, max_params = 50):

    def calc_limits(max_params = 50):
        # this function helps estaish the svd and gmm settings to stay within max_params

        valid_configs = [] # list of tuples (num_svd_components, num_gmm_components)

        for cov_type in ['spherical', 'diag', 'tied', 'full']:
            for svd_comp in range(1,20): 
                for gmm_comp in range(1,20): 
                    if ((svd_comp + svd_comp) * gmm_comp) * 2 <= max_params:
                        valid_configs.append((svd_comp, gmm_comp, cov_type))

        return(valid_configs)

    configs = calc_limits(max_params) # get the valid configurations

    top_accuracy_val = 0 # keeps track of top accuracy value
    top_accuracy_config = () # keeps track of config that creates top accuracy value
    
    for config in configs:
        accuracy = train_gmm(config[0], config[1], config[2])
        if accuracy > top_accuracy_val:
            top_accuracy_val = accuracy
            top_accuracy_config = config

    print("*********************************************************************************")
    print("The best accuracy score is", top_accuracy_val)
    print("To get it, set SVD comps to", top_accuracy_config[0], ", GMM comps to", top_accuracy_config[1],", and covariance type to", top_accuracy_config[2])

gmm_trials(sparse = True)
# Out:
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type spherical = 0.556930693069307
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type spherical = 0.5606435643564357
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type spherical = 0.5581683168316832
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type spherical = 0.5853960396039604
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type spherical = 0.5396039603960396
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type spherical = 0.5693069306930693
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type spherical = 0.5433168316831684
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type spherical = 0.5507425742574258
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type spherical = 0.5594059405940595
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type spherical = 0.5383663366336634
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type spherical = 0.5705445544554455
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type spherical = 0.5717821782178217
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type spherical = 0.5594059405940595
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type spherical = 0.5457920792079208
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type spherical = 0.5717821782178217
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type spherical = 0.5061881188118812
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type spherical = 0.525990099009901
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type spherical = 0.5408415841584159
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type spherical = 0.5433168316831684
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type spherical = 0.5556930693069307
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type spherical = 0.5754950495049505
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type spherical = 0.5160891089108911
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type spherical = 0.5420792079207921
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type spherical = 0.49876237623762376
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type spherical = 0.551980198019802
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type spherical = 0.5556930693069307
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type spherical = 0.5334158415841584
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type spherical = 0.5618811881188119
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type spherical = 0.5235148514851485
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type spherical = 0.5532178217821783
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type spherical = 0.5618811881188119
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type spherical = 0.5408415841584159
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type spherical = 0.5408415841584159
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type spherical = 0.5396039603960396
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type spherical = 0.5284653465346535
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type diag = 0.556930693069307
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type diag = 0.5606435643564357
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type diag = 0.5594059405940595
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type diag = 0.5853960396039604
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type diag = 0.5383663366336634
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type diag = 0.5581683168316832
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type diag = 0.5581683168316832
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type diag = 0.5346534653465347
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type diag = 0.556930693069307
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type diag = 0.5544554455445545
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type diag = 0.5532178217821783
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type diag = 0.5767326732673267
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type diag = 0.5495049504950495
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type diag = 0.5581683168316832
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type diag = 0.568069306930693
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type diag = 0.530940594059406
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type diag = 0.5346534653465347
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type diag = 0.5754950495049505
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type diag = 0.5420792079207921
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type diag = 0.5594059405940595
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type diag = 0.5594059405940595
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type diag = 0.5284653465346535
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type diag = 0.5433168316831684
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type diag = 0.5544554455445545
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type diag = 0.5532178217821783
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type diag = 0.5495049504950495
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type diag = 0.5507425742574258
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type diag = 0.5544554455445545
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type diag = 0.5507425742574258
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type diag = 0.5507425742574258
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type diag = 0.5581683168316832
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type diag = 0.5495049504950495
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type diag = 0.5321782178217822
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type diag = 0.5457920792079208
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type diag = 0.5086633663366337
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type tied = 0.556930693069307
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type tied = 0.5581683168316832
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type tied = 0.5581683168316832
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type tied = 0.5841584158415841
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type tied = 0.5594059405940595
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type tied = 0.5594059405940595
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type tied = 0.5581683168316832
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type tied = 0.5581683168316832
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type tied = 0.556930693069307
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type tied = 0.5556930693069307
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type tied = 0.5606435643564357
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type tied = 0.5655940594059405
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type tied = 0.5470297029702971
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type tied = 0.3873762376237624
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type tied = 0.5631188118811881
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type tied = 0.5618811881188119
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type tied = 0.5618811881188119
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type tied = 0.5668316831683168
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type tied = 0.5470297029702971
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type tied = 0.38613861386138615
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type tied = 0.5594059405940595
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type tied = 0.5445544554455446
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type tied = 0.5495049504950495
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type tied = 0.5532178217821783
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type tied = 0.5618811881188119
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type tied = 0.5742574257425742
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type tied = 0.556930693069307
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type tied = 0.5631188118811881
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type tied = 0.40470297029702973
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type tied = 0.568069306930693
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type tied = 0.5693069306930693
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type tied = 0.5643564356435643
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type tied = 0.5779702970297029
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type tied = 0.5544554455445545
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type tied = 0.6064356435643564
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type full = 0.556930693069307
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type full = 0.5594059405940595
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type full = 0.5581683168316832
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type full = 0.5853960396039604
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type full = 0.5383663366336634
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type full = 0.5581683168316832
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type full = 0.5457920792079208
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type full = 0.5358910891089109
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type full = 0.5272277227722773
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type full = 0.5631188118811881
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type full = 0.5556930693069307
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type full = 0.5643564356435643
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type full = 0.5470297029702971
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type full = 0.5816831683168316
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type full = 0.5594059405940595
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type full = 0.5544554455445545
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type full = 0.5482673267326733
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type full = 0.5841584158415841
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type full = 0.5408415841584159
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type full = 0.5779702970297029
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type full = 0.49133663366336633
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type full = 0.5297029702970297
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type full = 0.5532178217821783
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type full = 0.5693069306930693
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type full = 0.5544554455445545
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type full = 0.556930693069307
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type full = 0.5878712871287128
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type full = 0.5594059405940595
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type full = 0.5717821782178217
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type full = 0.5668316831683168
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type full = 0.5792079207920792
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type full = 0.5705445544554455
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type full = 0.5742574257425742
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type full = 0.5891089108910891
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type full = 0.5742574257425742
# *********************************************************************************
# The best accuracy score is 0.6064356435643564
# To get it, set SVD comps to 12 , GMM comps to 1 , and covariance type to tied

# %% [markdown]
# ### Result: Dimensionality reduction on the vectorized text field doesn't help

# %% [markdown]
# ### Next: Dimensionality reduction on all features

# %%
# THIS IS BOGUS BECAUSE IT CREATES TRAIN AND TEST DATA THAT HAVE ALL THE FIELDS

#Try using ALL features, even those not in the test data. 



#Normalize all fields (numeric)
min_max_scaler = preprocessing.MinMaxScaler()
mn_mx_scaler = min_max_scaler.fit_transform(
    train.select_dtypes(include = ['float64', 'int64','datetime64[ns]']).apply(pd.to_numeric).values)

#Split train and test data
x_train, x_test, y_train, y_test = train_test_split(
    mn_mx_scaler, 
    train_labels_master.values.ravel(), test_size=0.2, random_state=0)

# %%
gmm_trials(sparse = False)
# Out:
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type spherical = 0.6051980198019802
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type spherical = 0.5754950495049505
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type spherical = 0.5643564356435643
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type spherical = 0.5457920792079208
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type spherical = 0.5717821782178217
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type spherical = 0.5272277227722773
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type spherical = 0.5482673267326733
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type spherical = 0.49257425742574257
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type spherical = 0.5099009900990099
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type spherical = 0.5160891089108911
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type spherical = 0.49133663366336633
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type spherical = 0.48267326732673266
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type spherical = 0.5779702970297029
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type spherical = 0.6188118811881188
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type spherical = 0.6274752475247525
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type spherical = 0.6175742574257426
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type spherical = 0.6089108910891089
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type spherical = 0.599009900990099
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type spherical = 0.5779702970297029
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type spherical = 0.6349009900990099
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type spherical = 0.6497524752475248
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type spherical = 0.6670792079207921
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type spherical = 0.5792079207920792
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type spherical = 0.5074257425742574
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type spherical = 0.6311881188118812
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type spherical = 0.5742574257425742
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type spherical = 0.5445544554455446
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type spherical = 0.5853960396039604
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type spherical = 0.6274752475247525
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type spherical = 0.6002475247524752
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type spherical = 0.5928217821782178
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type spherical = 0.5928217821782178
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type spherical = 0.5977722772277227
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type spherical = 0.6002475247524752
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type spherical = 0.6014851485148515
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type diag = 0.6051980198019802
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type diag = 0.5792079207920792
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type diag = 0.5643564356435643
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type diag = 0.5470297029702971
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type diag = 0.5631188118811881
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type diag = 0.556930693069307
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type diag = 0.5111386138613861
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type diag = 0.5111386138613861
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type diag = 0.5099009900990099
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type diag = 0.4938118811881188
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type diag = 0.49876237623762376
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type diag = 0.5247524752475248
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type diag = 0.5606435643564357
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type diag = 0.6064356435643564
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type diag = 0.629950495049505
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type diag = 0.6113861386138614
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type diag = 0.6237623762376238
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type diag = 0.6113861386138614
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type diag = 0.5767326732673267
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type diag = 0.5371287128712872
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type diag = 0.556930693069307
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type diag = 0.5594059405940595
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type diag = 0.6138613861386139
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type diag = 0.5717821782178217
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type diag = 0.551980198019802
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type diag = 0.6274752475247525
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type diag = 0.5878712871287128
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type diag = 0.6547029702970297
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type diag = 0.47896039603960394
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type diag = 0.7029702970297029
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type diag = 0.7017326732673267
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type diag = 0.6918316831683168
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type diag = 0.6943069306930693
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type diag = 0.6881188118811881
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type diag = 0.7141089108910891
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type tied = 0.6051980198019802
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type tied = 0.5903465346534653
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type tied = 0.5643564356435643
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type tied = 0.5866336633663366
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type tied = 0.5915841584158416
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type tied = 0.5779702970297029
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type tied = 0.5556930693069307
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type tied = 0.551980198019802
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type tied = 0.5408415841584159
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type tied = 0.5445544554455446
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type tied = 0.530940594059406
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type tied = 0.5470297029702971
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type tied = 0.6373762376237624
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type tied = 0.6361386138613861
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type tied = 0.5878712871287128
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type tied = 0.5977722772277227
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type tied = 0.6336633663366337
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type tied = 0.6398514851485149
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type tied = 0.6992574257425742
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type tied = 0.7116336633663366
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type tied = 0.6943069306930693
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type tied = 0.676980198019802
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type tied = 0.6868811881188119
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type tied = 0.676980198019802
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type tied = 0.6745049504950495
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type tied = 0.6918316831683168
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type tied = 0.6707920792079208
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type tied = 0.6881188118811881
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type tied = 0.6856435643564357
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type tied = 0.7103960396039604
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type tied = 0.724009900990099
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type tied = 0.6670792079207921
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type tied = 0.6646039603960396
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type tied = 0.6522277227722773
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type tied = 0.6732673267326733
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type full = 0.6051980198019802
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type full = 0.5792079207920792
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type full = 0.5693069306930693
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type full = 0.5445544554455446
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type full = 0.5631188118811881
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type full = 0.556930693069307
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type full = 0.5482673267326733
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type full = 0.5012376237623762
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type full = 0.5173267326732673
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type full = 0.49133663366336633
# Accuracy score for 1 SVD comps, 11 GMM comps, Covariance type full = 0.5148514851485149
# Accuracy score for 1 SVD comps, 12 GMM comps, Covariance type full = 0.5655940594059405
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type full = 0.6373762376237624
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type full = 0.6051980198019802
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type full = 0.5618811881188119
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type full = 0.5705445544554455
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type full = 0.5495049504950495
# Accuracy score for 2 SVD comps, 6 GMM comps, Covariance type full = 0.5136138613861386
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type full = 0.6992574257425742
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type full = 0.4814356435643564
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type full = 0.46534653465346537
# Accuracy score for 3 SVD comps, 4 GMM comps, Covariance type full = 0.6237623762376238
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type full = 0.6868811881188119
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type full = 0.452970297029703
# Accuracy score for 4 SVD comps, 3 GMM comps, Covariance type full = 0.5160891089108911
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type full = 0.6918316831683168
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type full = 0.46905940594059403
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type full = 0.6881188118811881
# Accuracy score for 6 SVD comps, 2 GMM comps, Covariance type full = 0.568069306930693
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type full = 0.7103960396039604
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type full = 0.724009900990099
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type full = 0.6670792079207921
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type full = 0.6646039603960396
# Accuracy score for 11 SVD comps, 1 GMM comps, Covariance type full = 0.6522277227722773
# Accuracy score for 12 SVD comps, 1 GMM comps, Covariance type full = 0.6732673267326733
# *********************************************************************************
# The best accuracy score is 0.724009900990099
# To get it, set SVD comps to 8 , GMM comps to 1 , and covariance type to tied

# %%
#Try using just the features in common with train and test. 

#Normalize all fields (numeric)
min_max_scaler = preprocessing.MinMaxScaler()
mn_mx_scaler = min_max_scaler.fit_transform(
    train_data_master.select_dtypes(include = ['float64', 'int64','datetime64[ns]']).apply(pd.to_numeric).values)

#Split train and test data
x_train, x_test, y_train, y_test = train_test_split(
    mn_mx_scaler, 
    train_labels_master.values.ravel(), test_size=0.2, random_state=0)

# %%
gmm_trials(sparse = False, max_params = 40)
# Out:
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type spherical = 0.5445544554455446
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type spherical = 0.6027227722772277
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type spherical = 0.5371287128712872
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type spherical = 0.5643564356435643
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type spherical = 0.5965346534653465
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type spherical = 0.5816831683168316
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type spherical = 0.5606435643564357
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type spherical = 0.5321782178217822
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type spherical = 0.5358910891089109
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type spherical = 0.5383663366336634
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type spherical = 0.5643564356435643
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type spherical = 0.6311881188118812
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type spherical = 0.5779702970297029
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type spherical = 0.5606435643564357
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type spherical = 0.5284653465346535
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type spherical = 0.5606435643564357
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type spherical = 0.6237623762376238
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type spherical = 0.5915841584158416
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type spherical = 0.5643564356435643
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type spherical = 0.5977722772277227
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type spherical = 0.5693069306930693
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type spherical = 0.599009900990099
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type spherical = 0.5767326732673267
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type spherical = 0.5767326732673267
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type spherical = 0.5804455445544554
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type spherical = 0.5841584158415841
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type spherical = 0.5841584158415841
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type diag = 0.5445544554455446
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type diag = 0.6027227722772277
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type diag = 0.5334158415841584
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type diag = 0.5668316831683168
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type diag = 0.5965346534653465
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type diag = 0.5754950495049505
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type diag = 0.551980198019802
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type diag = 0.556930693069307
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type diag = 0.5482673267326733
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type diag = 0.5272277227722773
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type diag = 0.5804455445544554
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type diag = 0.6274752475247525
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type diag = 0.5173267326732673
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type diag = 0.5853960396039604
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type diag = 0.5915841584158416
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type diag = 0.6621287128712872
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type diag = 0.5235148514851485
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type diag = 0.6237623762376238
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type diag = 0.6707920792079208
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type diag = 0.594059405940594
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type diag = 0.6695544554455446
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type diag = 0.5284653465346535
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type diag = 0.6918316831683168
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type diag = 0.6918316831683168
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type diag = 0.7029702970297029
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type diag = 0.7079207920792079
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type diag = 0.7054455445544554
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type tied = 0.5445544554455446
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type tied = 0.5977722772277227
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type tied = 0.525990099009901
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type tied = 0.5655940594059405
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type tied = 0.5457920792079208
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type tied = 0.5198019801980198
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type tied = 0.5321782178217822
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type tied = 0.5433168316831684
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type tied = 0.5235148514851485
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type tied = 0.5457920792079208
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type tied = 0.5606435643564357
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type tied = 0.5581683168316832
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type tied = 0.5878712871287128
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type tied = 0.6039603960396039
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type tied = 0.5556930693069307
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type tied = 0.6868811881188119
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type tied = 0.6596534653465347
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type tied = 0.6633663366336634
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type tied = 0.6732673267326733
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type tied = 0.6707920792079208
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type tied = 0.6646039603960396
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type tied = 0.6683168316831684
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type tied = 0.6918316831683168
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type tied = 0.6943069306930693
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type tied = 0.6967821782178217
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type tied = 0.7103960396039604
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type tied = 0.7103960396039604
# Accuracy score for 1 SVD comps, 1 GMM comps, Covariance type full = 0.5445544554455446
# Accuracy score for 1 SVD comps, 2 GMM comps, Covariance type full = 0.6027227722772277
# Accuracy score for 1 SVD comps, 3 GMM comps, Covariance type full = 0.5544554455445545
# Accuracy score for 1 SVD comps, 4 GMM comps, Covariance type full = 0.568069306930693
# Accuracy score for 1 SVD comps, 5 GMM comps, Covariance type full = 0.5334158415841584
# Accuracy score for 1 SVD comps, 6 GMM comps, Covariance type full = 0.5903465346534653
# Accuracy score for 1 SVD comps, 7 GMM comps, Covariance type full = 0.5433168316831684
# Accuracy score for 1 SVD comps, 8 GMM comps, Covariance type full = 0.5606435643564357
# Accuracy score for 1 SVD comps, 9 GMM comps, Covariance type full = 0.5556930693069307
# Accuracy score for 1 SVD comps, 10 GMM comps, Covariance type full = 0.5792079207920792
# Accuracy score for 2 SVD comps, 1 GMM comps, Covariance type full = 0.5606435643564357
# Accuracy score for 2 SVD comps, 2 GMM comps, Covariance type full = 0.6027227722772277
# Accuracy score for 2 SVD comps, 3 GMM comps, Covariance type full = 0.4900990099009901
# Accuracy score for 2 SVD comps, 4 GMM comps, Covariance type full = 0.4542079207920792
# Accuracy score for 2 SVD comps, 5 GMM comps, Covariance type full = 0.4504950495049505
# Accuracy score for 3 SVD comps, 1 GMM comps, Covariance type full = 0.6868811881188119
# Accuracy score for 3 SVD comps, 2 GMM comps, Covariance type full = 0.43564356435643564
# Accuracy score for 3 SVD comps, 3 GMM comps, Covariance type full = 0.5408415841584159
# Accuracy score for 4 SVD comps, 1 GMM comps, Covariance type full = 0.6732673267326733
# Accuracy score for 4 SVD comps, 2 GMM comps, Covariance type full = 0.676980198019802
# Accuracy score for 5 SVD comps, 1 GMM comps, Covariance type full = 0.6646039603960396
# Accuracy score for 5 SVD comps, 2 GMM comps, Covariance type full = 0.5792079207920792
# Accuracy score for 6 SVD comps, 1 GMM comps, Covariance type full = 0.6918316831683168
# Accuracy score for 7 SVD comps, 1 GMM comps, Covariance type full = 0.6943069306930693
# Accuracy score for 8 SVD comps, 1 GMM comps, Covariance type full = 0.6967821782178217
# Accuracy score for 9 SVD comps, 1 GMM comps, Covariance type full = 0.7103960396039604
# Accuracy score for 10 SVD comps, 1 GMM comps, Covariance type full = 0.7103960396039604
# *********************************************************************************
# The best accuracy score is 0.7103960396039604
# To get it, set SVD comps to 9 , GMM comps to 1 , and covariance type to tied

# %% [markdown]
# ### Reduce vectorized word field, plug it into logistic regression with other features

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#Create Sparse matrix of words
#count_vect = CountVectorizer()
#count_vect_ft = count_vect.fit_transform(train_data_master['request_text_edit_aware']) # valid?

count_vect = CountVectorizer()

x_train = train_data_master[:3232]['request_text_edit_aware']
x_test = train_data_master[3232:]['request_text_edit_aware'] 
#y_train, y_test = train_labels_master.values.ravel()[:3232], train_labels_master.values.ravel()[3232:]

train_features = count_vect.fit_transform(x_train)
dev_features = count_vect.transform(x_test)

print(x_train.shape, new_var.shape)

#Reduce the vectorized word feature to small number of numerical components
svd_comps = 70
# tfidf 100 not bad, tfid 250
svd = TruncatedSVD(n_components=svd_comps)
svd_ft_tr = svd.fit_transform(train_features)
svd_ft_dv = svd.fit_transform(dev_features)
svd_ft = np.concatenate((svd_ft_tr, svd_ft_dv), axis=0)

# add the newly reduced text field feature to the train and test data
train_data_SVD = train_data_master.copy(deep = True)
for comp in range(svd_comps):
    train_data_SVD['SVD'+str(comp)] = svd_ft[:,comp]

#Normalize all fields (numeric)
min_max_scaler = preprocessing.MinMaxScaler()
mn_mx_scaler = min_max_scaler.fit_transform(train_data_SVD.select_dtypes(include = ['float64', 'int64','datetime64[ns]']).apply(pd.to_numeric).values)

#Split train and test data
x_train, x_test = mn_mx_scaler[:3232], mn_mx_scaler[3232:] 
y_train, y_test = train_labels_master[:3232].values.ravel(), train_labels_master[3232:].values.ravel()
# Out:
# (3232,) (3232, 11063)

# %%
# do logistic regression on our new train data

def model_report(title, y_test, predictions):

    """
    Output: Classification report, confusion matrix, and ROC curve
    """
    print(title)
    print("---------")
    print(classification_report(y_test, predictions))

    cm = metrics.confusion_matrix(y_test, predictions)
    plt.figure(figsize=(3,3))
    sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Accuracy: {0}'.format(round(metrics.accuracy_score(y_test, predictions),2))
    plt.title(all_sample_title, size = 15)
    plt.show()
    
    fpr, tpr, threshold = metrics.roc_curve(y_test, predictions)
    roc_auc = metrics.auc(fpr, tpr)

    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    
#Train Model
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)

#Output model report
model_report("Logistic Regression (using only common numeric fields)",y_test, predictions)
# Out:
# Logistic Regression (using only common numeric fields)
# ---------
#              precision    recall  f1-score   support
#
#       False       0.76      0.98      0.86       612
#        True       0.50      0.06      0.10       196
#
# avg / total       0.70      0.76      0.68       808

# %% [markdown]
# ### Results
# * Reducing the vectorized word feature got us to 0.68 accuracy - the exact same accuracy that Naive Bayes got us.
# * Reducing all the features (even those not in the test set) got us to 0.72 accuracy - a bit less than the 0.75 accuracy from logistic regression on the features.
# * Reducing just the features that are shared by train and test sets got us to 0.71 accuracy - even further from the 0.75 accuracy of logistic regression.
# * Vectorizing the text field, reducing it through SVD to 5 components, adding it to the train data, and running logistic regression again did improve accuracy by small margins.

# %% [markdown]
# # Ensemble
# Try to do Naive Bayes first on the text field, store the results in a new field.
# Then run logistic regression.

# %%
# a few problems -- were the train and test data properly vectorized -- one should be fit_trans
# the other should jsut be transformed!

#Create Sparse matrix of words
count_vect = CountVectorizer()
x_train, x_test, y_train, y_test = train_test_split(train_data_master['request_text_edit_aware'], train_labels_master.values.ravel(), test_size=0.2, random_state=0)
train_features = count_vect.fit_transform(x_train)
dev_features = count_vect.transform(x_test)

#Train NB
nb = BernoulliNB()
nb_fit = nb.fit(train_features, y_train)
predictions = nb_fit.predict(dev_features)
print(metrics.f1_score(y_test, predictions))
print('Accuracy: {0}'.format(round(metrics.accuracy_score(y_test, predictions),2)))
print(train_features.shape, dev_features.shape)

predictions = nb_fit.feature_log_prob_
print(predictions.shape)

#    tfvectoriz = TfidfVectorizer()
#    train_probs = tfvectoriz.fit_transform(train_data)
#    dev_probs = tfvectoriz.transform(dev_data)


#svd_comps = 5 # after some trial and error, this was the best
#svd = TruncatedSVD(n_components=svd_comps)
#svd_ft = svd.fit_transform(count_vect_ft)

# add the newly reduced text field feature to the train and test data
#train_data_SVD = train_data_master.copy(deep = True)
#for comp in range(svd_comps):
#    train_data_SVD['SVD'+str(comp)] = svd_ft[:,comp]

#Normalize all fields (numeric)
#min_max_scaler = preprocessing.MinMaxScaler()
#mn_mx_scaler = min_max_scaler.fit_transform(train_data_SVD.select_dtypes(include = ['float64', 'int64','datetime64[ns]']).apply(pd.to_numeric).values)

#Split train and test data
#x_train, x_test, y_train, y_test = train_test_split(
#    mn_mx_scaler, 
#    train_labels_master.values.ravel(), test_size=0.2, random_state=0)
# Out:
# 0.27988338192419826
# Accuracy: 0.69
# (3232, 10974) (808, 10974)
# (2, 10974)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-c49f4f446499> in <module>()
#      18 predictions = nb_fit.feature_log_prob_
#      19 print(predictions.shape)
# ---> 20 predict_proba
#      21
#      22 #svd_comps = 5 # after some trial and error, this was the best
#
# NameError: name 'predict_proba' is not defined
